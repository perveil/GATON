# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

#DGL
import dgl

from dataset import DocData
from model import GATON,MyLoss
from evaluate import computeClassificationMetric,computeCoherence
import random

from apex import amp
# Out:
# `fused_weight_gradient_mlp_cuda` module not found. gradient accumulation fusion with weight gradient computation disabled.

# %%
seed=2022
np.random.seed(seed)
random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
#超参
topic_num=20
graph_input_dim=64
graph_hidden_dim=128
device="cuda:0"

head_num=2

epochs=20

data=DocData("/home/v-ruiruiwang/notebooks/code/GATON/data/20NG_mindf_97_vocab_2004_pretrain.pkl")

# %%
model = GATON(
    data.graph,
    topic_num,
    data.vocabulary_size,
    data.word_embedding_size,
    graph_input_dim,
    graph_hidden_dim,
    head_num
    ).to(device)

data.graph.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=2e-3,weight_decay=0.005)
loss_fn=MyLoss()

model, optimizer = amp.initialize(model, optimizer, opt_level="O1") # 这里是“欧一”，不是“零一”



model.train()

for epoch in range(epochs):

    doc_input = data.doc_word_frequency.to(device) # 初始的 doc 表示 
    word_input = data.word_embeddings.to(device)    #初始的 word 表示

    doc_topic_prob,word_topic_prob = model(doc_input,word_input)

    #计算loss
    doc_word_occ = torch.matmul(doc_topic_prob,word_topic_prob.permute(1,0))
    recon_loss = loss_fn(doc_word_occ,doc_input)
    total_loss=recon_loss
    optimizer.zero_grad()
    # total_loss.backward()
    
    # amp
    with amp.scale_loss(total_loss, optimizer) as scaled_loss:
        scaled_loss.backward()
    
    optimizer.step()

    print("==========================================================================")
    print("epoch start ====================================================================")
    print('cur reconstruct loss:',recon_loss.item())
    # print('cur classfication loss:',class_loss.item())
    print('cur total  loss:',total_loss.item())
    
    model.eval()
    with torch.no_grad():
        word_topic_dis = word_topic_prob.cpu().numpy().transpose()
        doc_topic_dis = doc_topic_prob.cpu().argmax(dim=1).numpy()
    #验证分类
    computeClassificationMetric(doc_topic_dis,np.array(data.labels),True)
    #验证Topic Coherence
    computeCoherence(word_topic_dis,data.ins_tr,data.tgt_keys,data.idx2word,10,True)

    print("epoch end====================================================================")
    print("==========================================================================")
# Out:
# ==========================================================================
# epoch start ====================================================================
# cur reconstruct loss: 82712.7578125
# cur total  loss: 82712.7578125
# ==========================================================================
# f1 macro: 0.008963552550904544 f1 micro: 0.052646291464778235 precision: 0.052646291464778235 accuracy: 0.052646291464778235 recall 0.052646291464778235
# ==========================================================================
# Average Topic Coherence = 0.116
# Average  gaton Topic Coherence = -269.989
# ==========================================================================
# 0.15551234996416038
# 主题先验===================================================================
# ['atheism', 'atheists', 'religion', 'atheist', 'god']
# ['covered', 'due', 'demand', 'users', 'sleep', 'fast', 'explain', 'dave', 'today', 'colorado']
# 模型结果====================================================================
# ==========================================================================
# 0.17886358127807678
# 主题先验===================================================================
# ['graphics', 'image', 'images', 'gif', 'format']
# ['side', 'due', 'demand', 'increased', 'users', 'connect', 'dave', 'fast', 'explain', 'today']
# 模型结果====================================================================
# ==========================================================================
# 0.12602252297565253
# 主题先验===================================================================
# ['windows', 'dos', 'file', 'ms', 'microsoft']
# ['os', 'side', 'covered', 'due', 'demand', 'increased', 'users', 'connect', 'sleep', 'explain']
# 模型结果====================================================================
# ==========================================================================
# 0.16636105927393408
# 主题先验===================================================================
# ['ide', 'controller', 'card', 'bus', 'drive']
# ['side', 'due', 'demand', 'users', 'increased', 'connect', 'sleep', 'explain', 'fast', 'dave']
# 模型结果====================================================================
# ==========================================================================
# 0.10086242697862302
# 主题先验===================================================================
# ['mac', 'apple', 'monitor', 'scsi', 'se']
# ['activities', 'replacement', 'guys', 'serve', 'depending', 'assumption', 'afraid', 'idea', 'community', 'ability']
# 模型结果====================================================================
# ==========================================================================
# 0.1395982662825341
# 主题先验===================================================================
# ['window', 'motif', 'server', 'widget', 'application']
# ['os', 'side', 'covered', 'demand', 'users', 'fast', 'explain', 'dave', 'colorado', 'mine']
# 模型结果====================================================================
# ==========================================================================
# 0.15774007651368485
# 主题先验===================================================================
# ['sale', 'shipping', 'offer', 'condition', 'sell']
# ['os', 'side', 'due', 'increased', 'users', 'today', 'argument', 'colorado', 'driver', 'primarily']
# 模型结果====================================================================
# ==========================================================================
# 0.1631901018330917
# 主题先验===================================================================
# ['car', 'cars', 'engine', 'ford', 'dealer']
# ['os', 'side', 'due', 'covered', 'demand', 'users', 'connect', 'fast', 'explain', 'dave']
# 模型结果====================================================================
# ==========================================================================
# 0.18166175523692843
# 主题先验===================================================================
# ['bike', 'dod', 'ride', 'riding', 'rear']
# ['os', 'side', 'covered', 'primarily', 'due', 'demand', 'surprised', 'increased', 'users', 'connect']
# 模型结果====================================================================
# ==========================================================================
# 0.17349271631490557
# 主题先验===================================================================
# ['baseball', 'game', 'games', 'players', 'league']
# ['covered', 'users', 'connect', 'sleep', 'explain', 'dave', 'fast', 'today', 'colorado', 'primarily']
# 模型结果====================================================================
# ==========================================================================
# -0.062210445795542746
# 主题先验===================================================================
# ['hockey', 'game', 'team', 'nhl', 'playoffs']
# ['driver', 'minutes', 'gay', 'standing', 'rear', 'cc', 'french', 'cover', 'dos', 'space']
# 模型结果====================================================================
# ==========================================================================
# 0.13699629438074423
# 主题先验===================================================================
# ['encryption', 'clipper', 'key', 'nsa', 'keys']
# ['os', 'side', 'due', 'demand', 'increased', 'connect', 'dave', 'explain', 'fast', 'colorado']
# 模型结果====================================================================
# ==========================================================================
# 0.08785468962321452
# 主题先验===================================================================
# ['circuit', 'electronics', 'output', 'radio', 'battery']
# ['due', 'covered', 'demand', 'increased', 'sleep', 'today', 'driver', 'argument', 'mine', 'equivalent']
# 模型结果====================================================================
# ==========================================================================
# 0.06346735282581753
# 主题先验===================================================================
# ['doctor', 'medical', 'disease', 'patients', 'gordon']
# ['sleep', 'driver', 'live', 'greek', 'forgot', 'innocent', 'sort', 'research', 'search', 'tradition']
# 模型结果====================================================================
# ==========================================================================
# 0.10852489121475473
# 主题先验===================================================================
# ['space', 'orbit', 'shuttle', 'nasa', 'launch']
# ['os', 'due', 'covered', 'demand', 'increased', 'connect', 'sleep', 'today', 'primarily', 'argument']
# 模型结果====================================================================
# ==========================================================================
# 0.011304891923761004
# 主题先验===================================================================
# ['god', 'christ', 'church', 'jesus', 'christian']
# ['recommend', 'innocent', 'sort', 'defend', 'ancient', 'arabs', 'possibility', 'los', 'decided', 'holding']
# 模型结果====================================================================
# ==========================================================================
# 0.1383559362030505
# 主题先验===================================================================
# ['gun', 'guns', 'firearms', 'fbi', 'weapons']
# ['connect', 'purchased', 'remains', 'stats', 'learned', 'fine', 'purpose', 'moment', 'complete', 'setting']
# 模型结果====================================================================
# ==========================================================================
# 0.13144367790971784
# 主题先验===================================================================
# ['israel', 'israeli', 'arab', 'armenian', 'armenians']
# ['require', 'gay', 'mention', 'immediately', 'act', 'item', 'standing', 'figures', 'engineering', 'works']
# 模型结果====================================================================
# ==========================================================================
# 0.06963759668510412
# 主题先验===================================================================
# ['gay', 'people', 'clinton', 'government', 'economic']
# ['dr', 'responsibility', 'amazing', 'applies', 'cc', 'cd', 'model', 'guys', 'designed', 'share']
# 模型结果====================================================================
# ==========================================================================
# 0.0939168878459392
# 主题先验===================================================================
# ['jesus', 'god', 'bible', 'christian', 'kent']
# ['os', 'side', 'increased', 'connect', 'sleep', 'fast', 'dave', 'explain', 'primarily', 'argument']
# 模型结果====================================================================
# epoch end====================================================================
# ==========================================================================
# ==========================================================================
# epoch start ====================================================================
# cur reconstruct loss: 82706.9921875
# cur total  loss: 82706.9921875
# ==========================================================================
# f1 macro: 0.004976093500973968 f1 micro: 0.0523667536339918 precision: 0.0523667536339918 accuracy: 0.0523667536339918 recall 0.0523667536339918
# ==========================================================================
# Average Topic Coherence = 0.151
# Average  gaton Topic Coherence = -237.289
# ==========================================================================
# -0.0017949164619571621
# 主题先验===================================================================
# ['atheism', 'atheists', 'religion', 'atheist', 'god']
# ['scsi', 'ide', 'encrypted', 'max', 'bios', 'chip', 'controller', 'encryption', 'connect', 'modem']
# 模型结果====================================================================
# ==========================================================================
# 0.1901566885481444
# 主题先验===================================================================
# ['graphics', 'image', 'images', 'gif', 'format']
# ['la', 'shots', 'playoff', 'rangers', 'sp', 'detroit', 'pp', 'ah', 'van', 'playoffs']
# 模型结果====================================================================
# ==========================================================================
# 0.3627239407921779
# 主题先验===================================================================
# ['windows', 'dos', 'file', 'ms', 'microsoft']
# ['gods', 'morality', 'belief', 'atheism', 'god', 'spirit', 'objective', 'eternal', 'faith', 'atheists']
# 模型结果====================================================================
# ==========================================================================
# 0.06754654390475422
# 主题先验===================================================================
# ['ide', 'controller', 'card', 'bus', 'drive']
# ['max', 'patients', 'patient', 'orbit', 'shuttle', 'fuel', 'objective', 'science', 'energy', 'treatment']
# 模型结果====================================================================
# ==========================================================================
# 0.044614767612335834
# 主题先验===================================================================
# ['mac', 'apple', 'monitor', 'scsi', 'se']
# ['max', 'pain', 'patients', 'patient', 'disease', 'doctors', 'tm', 'treatment', 'insurance', 'medical']
# 模型结果====================================================================
# ==========================================================================
# 0.3277349572914509
# 主题先验===================================================================
# ['window', 'motif', 'server', 'widget', 'application']
# ['scsi', 'ide', 'bios', 'drives', 'controller', 'cpu', 'floppy', 'rom', 'backup', 'specs']
# 模型结果====================================================================
# ==========================================================================
# 0.101571898977932
# 主题先验===================================================================
# ['sale', 'shipping', 'offer', 'condition', 'sell']
# ['max', 'amendment', 'crimes', 'firearms', 'sex', 'court', 'sexual', 'drugs', 'drug', 'tm']
# 模型结果====================================================================
# ==========================================================================
# -0.09679470188250675
# 主题先验===================================================================
# ['car', 'cars', 'engine', 'ford', 'dealer']
# ['max', 'dealer', 'scsi', 'tax', 'sale', 'privacy', 'manuals', 'encrypted', 'company', 'packages']
# 模型结果====================================================================
# ==========================================================================
# -0.11977990580305882
# 主题先验===================================================================
# ['bike', 'dod', 'ride', 'riding', 'rear']
# ['van', 'la', 'ah', 'max', 'rear', 'shots', 'boot', 'tm', 'bike', 'stereo']
# 模型结果====================================================================
# ==========================================================================
# 0.18200657296675493
# 主题先验===================================================================
# ['baseball', 'game', 'games', 'players', 'league']
# ['font', 'fonts', 'characters', 'microsoft', 'development', 'music', 'satellite', 'education', 'program', 'mission']
# 模型结果====================================================================
# ==========================================================================
# 0.22982216301170505
# 主题先验===================================================================
# ['hockey', 'game', 'team', 'nhl', 'playoffs']
# ['pp', 'sp', 'la', 'ah', 'shots', 'van', 'ny', 'rangers', 'period', 'louis']
# 模型结果====================================================================
# ==========================================================================
# 0.3803698864542087
# 主题先验===================================================================
# ['encryption', 'clipper', 'key', 'nsa', 'keys']
# ['gif', 'gov', 'anonymous', 'usenet', 'max', 'ftp', 'pub', 'motif', 'internet', 'addresses']
# 模型结果====================================================================
# ==========================================================================
# -0.019333225840908408
# 主题先验===================================================================
# ['circuit', 'electronics', 'output', 'radio', 'battery']
# ['scsi', 'turkish', 'genocide', 'turks', 'isa', 'muslim', 'minority', 'controller', 'jews', 'print']
# 模型结果====================================================================
# ==========================================================================
# -0.21523959238082524
# 主题先验===================================================================
# ['doctor', 'medical', 'disease', 'patients', 'gordon']
# ['ah', 'arabs', 'arab', 'israeli', 'baseball', 'hockey', 'jews', 'clinton', 'fans', 'sports']
# 模型结果====================================================================
# ==========================================================================
# 0.35295155239074033
# 主题先验===================================================================
# ['space', 'orbit', 'shuttle', 'nasa', 'launch']
# ['windows', 'dos', 'font', 'fonts', 'unix', 'microsoft', 'desktop', 'os', 'graphics', 'drivers']
# 模型结果====================================================================
# ==========================================================================
# 0.45100460762736316
# 主题先验===================================================================
# ['god', 'christ', 'church', 'jesus', 'christian']
# ['max', 'turks', 'armenians', 'soldiers', 'armenian', 'serdar', 'argic', 'genocide', 'muslim', 'burned']
# 模型结果====================================================================
# ==========================================================================
# 0.30446046393607457
# 主题先验===================================================================
# ['gun', 'guns', 'firearms', 'fbi', 'weapons']
# ['pp', 'shots', 'detroit', 'buffalo', 'rangers', 'pittsburgh', 'louis', 'sp', 'period', 'playoff']
# 模型结果====================================================================
# ==========================================================================
# 0.25821199128995764
# 主题先验===================================================================
# ['israel', 'israeli', 'arab', 'armenian', 'armenians']
# ['greek', 'turkish', 'arab', 'arabs', 'jewish', 'jews', 'turkey', 'spirit', 'bible', 'turks']
# 模型结果====================================================================
# ==========================================================================
# 0.35041324032630405
# 主题先验===================================================================
# ['gay', 'people', 'clinton', 'government', 'economic']
# ['max', 'tm', 'la', 'ma', 'st', 'ah', 'au', 'fi', 'van', 'mr']
# 模型结果====================================================================
# ==========================================================================
# -0.13520658530801255
# 主题先验===================================================================
# ['jesus', 'god', 'bible', 'christian', 'kent']
# ['os', 'rear', 'desktop', 'honda', 'apple', 'scsi', 'mac', 'keyboard', 'chips', 'mouse']
# 模型结果====================================================================
# epoch end====================================================================
# ==========================================================================
# ==========================================================================
# epoch start ====================================================================
# cur reconstruct loss: 82700.4375
# cur total  loss: 82700.4375
# ==========================================================================
# f1 macro: 0.004976093500973968 f1 micro: 0.0523667536339918 precision: 0.0523667536339918 accuracy: 0.0523667536339918 recall 0.0523667536339918
# ==========================================================================
# Average Topic Coherence = 0.118
# Average  gaton Topic Coherence = -242.272
# ==========================================================================
# -0.013176080618893206
# 主题先验===================================================================
# ['atheism', 'atheists', 'religion', 'atheist', 'god']
# ['max', 'ide', 'scsi', 'ma', 'tm', 'sp', 'encrypted', 'controller', 'bios', 'ah']
# 模型结果====================================================================
# ==========================================================================
# 0.19015668854814435
# 主题先验===================================================================
# ['graphics', 'image', 'images', 'gif', 'format']
# ['la', 'sp', 'ah', 'shots', 'rangers', 'playoff', 'pp', 'detroit', 'van', 'playoffs']
# 模型结果====================================================================
# ==========================================================================
# 0.3627239407921779
# 主题先验===================================================================
# ['windows', 'dos', 'file', 'ms', 'microsoft']
# ['morality', 'gods', 'belief', 'atheism', 'objective', 'god', 'spirit', 'faith', 'eternal', 'atheists']
# 模型结果====================================================================
# ==========================================================================
# -0.08997176375753525
# 主题先验===================================================================
# ['ide', 'controller', 'card', 'bus', 'drive']
# ['max', 'patients', 'theory', 'science', 'fuel', 'objective', 'gay', 'energy', 'rear', 'patient']
# 模型结果====================================================================
# ==========================================================================
# -0.12766760601399582
# 主题先验===================================================================
# ['mac', 'apple', 'monitor', 'scsi', 'se']
# ['max', 'tm', 'ah', 'pain', 'patients', 'patient', 'doug', 'disease', 'doctors', 'treatment']
# 模型结果====================================================================
# ==========================================================================
# 0.3786772862741416
# 主题先验===================================================================
# ['window', 'motif', 'server', 'widget', 'application']
# ['scsi', 'ide', 'bios', 'drives', 'rom', 'cpu', 'controller', 'floppy', 'backup', 'disk']
# 模型结果====================================================================
# ==========================================================================
# 0.14295810644887397
# 主题先验===================================================================
# ['sale', 'shipping', 'offer', 'condition', 'sell']
# ['amendment', 'drugs', 'sex', 'crimes', 'drug', 'court', 'sexual', 'firearms', 'max', 'homosexual']
# 模型结果====================================================================
# ==========================================================================
# -0.09679470188250675
# 主题先验===================================================================
# ['car', 'cars', 'engine', 'ford', 'dealer']
# ['max', 'dealer', 'tax', 'privacy', 'company', 'scsi', 'manuals', 'sale', 'encrypted', 'packages']
# 模型结果====================================================================
# ==========================================================================
# -0.0415337316171848
# 主题先验===================================================================
# ['bike', 'dod', 'ride', 'riding', 'rear']
# ['la', 'van', 'ah', 'max', 'tm', 'shots', 'rear', 'air', 'boot', 'bike']
# 模型结果====================================================================
# ==========================================================================
# 0.2616021227871642
# 主题先验===================================================================
# ['baseball', 'game', 'games', 'players', 'league']
# ['font', 'characters', 'microsoft', 'fonts', 'windows', 'music', 'education', 'software', 'program', 'formats']
# 模型结果====================================================================
# ==========================================================================
# 0.15764048835463668
# 主题先验===================================================================
# ['hockey', 'game', 'team', 'nhl', 'playoffs']
# ['sp', 'ah', 'pp', 'la', 'shots', 'van', 'ny', 'rangers', 'ma', 'doug']
# 模型结果====================================================================
# ==========================================================================
# 0.42569830568214295
# 主题先验===================================================================
# ['encryption', 'clipper', 'key', 'nsa', 'keys']
# ['gif', 'anonymous', 'gov', 'usenet', 'ftp', 'pub', 'motif', 'internet', 'libraries', 'server']
# 模型结果====================================================================
# ==========================================================================
# -0.021195423965661334
# 主题先验===================================================================
# ['circuit', 'electronics', 'output', 'radio', 'battery']
# ['scsi', 'print', 'copies', 'minority', 'controller', 'turkish', 'isa', 'port', 'printer', 'pc']
# 模型结果====================================================================
# ==========================================================================
# -0.2494536843380694
# 主题先验===================================================================
# ['doctor', 'medical', 'disease', 'patients', 'gordon']
# ['ah', 'max', 'tm', 'sp', 'ma', 'hockey', 'arabs', 'batf', 'arab', 'air']
# 模型结果====================================================================
# ==========================================================================
# 0.3545307873988986
# 主题先验===================================================================
# ['space', 'orbit', 'shuttle', 'nasa', 'launch']
# ['windows', 'dos', 'microsoft', 'font', 'fonts', 'desktop', 'unix', 'graphics', 'shareware', 'zip']
# 模型结果====================================================================
# ==========================================================================
# 0.17717955364388072
# 主题先验===================================================================
# ['god', 'christ', 'church', 'jesus', 'christian']
# ['max', 'ah', 'tm', 'turks', 'armenians', 'serdar', 'argic', 'armenian', 'soldiers', 'genocide']
# 模型结果====================================================================
# ==========================================================================
# 0.06749854809183459
# 主题先验===================================================================
# ['gun', 'guns', 'firearms', 'fbi', 'weapons']
# ['pp', 'sp', 'shots', 'detroit', 'buffalo', 'rangers', 'louis', 'pittsburgh', 'ah', 'serdar']
# 模型结果====================================================================
# ==========================================================================
# 0.276529625414703
# 主题先验===================================================================
# ['israel', 'israeli', 'arab', 'armenian', 'armenians']
# ['greek', 'turkish', 'arab', 'arabs', 'turkey', 'ah', 'turks', 'jewish', 'jews', 'spirit']
# 模型结果====================================================================
# ==========================================================================
# 0.350413240326304
# 主题先验===================================================================
# ['gay', 'people', 'clinton', 'government', 'economic']
# ['max', 'tm', 'la', 'ma', 'ah', 'st', 'au', 'fi', 'van', 'mr']
# 模型结果====================================================================
# ==========================================================================
# -0.13588286175399328
# 主题先验===================================================================
# ['jesus', 'god', 'bible', 'christian', 'kent']
# ['desktop', 'apple', 'os', 'rear', 'mac', 'keyboard', 'scsi', 'microsoft', 'chips', 'honda']
# 模型结果====================================================================
# epoch end====================================================================
# ==========================================================================
# ==========================================================================
# epoch start ====================================================================
# cur reconstruct loss: 82693.0859375
# cur total  loss: 82693.0859375
# ==========================================================================
# f1 macro: 0.005483084297329542 f1 micro: 0.049944092433842714 precision: 0.049944092433842714 accuracy: 0.049944092433842714 recall 0.049944092433842714
# ==========================================================================
# Average Topic Coherence = 0.169
# Average  gaton Topic Coherence = -235.265
# ==========================================================================
# -0.013176080618893193
# 主题先验===================================================================
# ['atheism', 'atheists', 'religion', 'atheist', 'god']
# ['max', 'tm', 'ah', 'sp', 'ma', 'ide', 'scsi', 'controller', 'bios', 'encrypted']
# 模型结果====================================================================
# ==========================================================================
# 0.1901566885481444
# 主题先验===================================================================
# ['graphics', 'image', 'images', 'gif', 'format']
# ['la', 'ah', 'sp', 'shots', 'rangers', 'pp', 'playoff', 'van', 'detroit', 'playoffs']
# 模型结果====================================================================
# ==========================================================================
# 0.36272394079217785
# 主题先验===================================================================
# ['windows', 'dos', 'file', 'ms', 'microsoft']
# ['morality', 'gods', 'belief', 'atheism', 'objective', 'faith', 'atheists', 'god', 'spirit', 'eternal']
# 模型结果====================================================================
# ==========================================================================
# -0.05229715686126875
# 主题先验===================================================================
# ['ide', 'controller', 'card', 'bus', 'drive']
# ['theory', 'patients', 'science', 'rear', 'gay', 'objective', 'fuel', 'interpretation', 'sex', 'absolute']
# 模型结果====================================================================
# ==========================================================================
# 0.04269468778725498
# 主题先验===================================================================
# ['mac', 'apple', 'monitor', 'scsi', 'se']
# ['max', 'tm', 'ah', 'sp', 'ma', 'doug', 'pain', 'pp', 'pittsburgh', 'gordon']
# 模型结果====================================================================
# ==========================================================================
# 0.2972359545997066
# 主题先验===================================================================
# ['window', 'motif', 'server', 'widget', 'application']
# ['scsi', 'rom', 'drives', 'disk', 'bios', 'card', 'backup', 'copies', 'cpu', 'floppy']
# 模型结果====================================================================
# ==========================================================================
# 0.18855319872389495
# 主题先验===================================================================
# ['sale', 'shipping', 'offer', 'condition', 'sell']
# ['amendment', 'entry', 'output', 'drug', 'drugs', 'sex', 'rate', 'court', 'theory', 'crimes']
# 模型结果====================================================================
# ==========================================================================
# 0.039376097335389826
# 主题先验===================================================================
# ['car', 'cars', 'engine', 'ford', 'dealer']
# ['dealer', 'privacy', 'max', 'company', 'tax', 'packages', 'encrypted', 'companies', 'manuals', 'software']
# 模型结果====================================================================
# ==========================================================================
# 0.12992724137458286
# 主题先验===================================================================
# ['bike', 'dod', 'ride', 'riding', 'rear']
# ['max', 'ah', 'la', 'van', 'tm', 'shots', 'air', 'rear', 'ny', 'soldiers']
# 模型结果====================================================================
# ==========================================================================
# 0.3180128578275844
# 主题先验===================================================================
# ['baseball', 'game', 'games', 'players', 'league']
# ['microsoft', 'characters', 'windows', 'font', 'software', 'fonts', 'formats', 'format', 'music', 'program']
# 模型结果====================================================================
# ==========================================================================
# 0.19439422083166802
# 主题先验===================================================================
# ['hockey', 'game', 'team', 'nhl', 'playoffs']
# ['ah', 'sp', 'pp', 'la', 'ma', 'shots', 'van', 'ny', 'rangers', 'buffalo']
# 模型结果====================================================================
# ==========================================================================
# 0.42569830568214295
# 主题先验===================================================================
# ['encryption', 'clipper', 'key', 'nsa', 'keys']
# ['gif', 'anonymous', 'motif', 'ftp', 'pub', 'usenet', 'internet', 'gov', 'libraries', 'server']
# 模型结果====================================================================
# ==========================================================================
# 0.30184293650262817
# 主题先验===================================================================
# ['circuit', 'electronics', 'output', 'radio', 'battery']
# ['scsi', 'print', 'copies', 'printer', 'pc', 'port', 'modem', 'card', 'controller', 'ports']
# 模型结果====================================================================
# ==========================================================================
# -0.2347407250437377
# 主题先验===================================================================
# ['doctor', 'medical', 'disease', 'patients', 'gordon']
# ['ah', 'max', 'tm', 'sp', 'ma', 'air', 'batf', 'hockey', 'dod', 'arabs']
# 模型结果====================================================================
# ==========================================================================
# 0.3585837391145303
# 主题先验===================================================================
# ['space', 'orbit', 'shuttle', 'nasa', 'launch']
# ['windows', 'microsoft', 'dos', 'desktop', 'font', 'fonts', 'unix', 'characters', 'shareware', 'graphics']
# 模型结果====================================================================
# ==========================================================================
# 0.008522421151418217
# 主题先验===================================================================
# ['god', 'christ', 'church', 'jesus', 'christian']
# ['max', 'ah', 'tm', 'serdar', 'sp', 'argic', 'turks', 'armenians', 'armenian', 'genocide']
# 模型结果====================================================================
# ==========================================================================
# 0.1793034666420445
# 主题先验===================================================================
# ['gun', 'guns', 'firearms', 'fbi', 'weapons']
# ['sp', 'ah', 'pp', 'max', 'shots', 'detroit', 'buffalo', 'tm', 'rangers', 'louis']
# 模型结果====================================================================
# ==========================================================================
# 0.21300200934493113
# 主题先验===================================================================
# ['israel', 'israeli', 'arab', 'armenian', 'armenians']
# ['ah', 'greek', 'turkish', 'max', 'turkey', 'pp', 'arab', 'arabs', 'turks', 'armenia']
# 模型结果====================================================================
# ==========================================================================
# 0.35278444145797044
# 主题先验===================================================================
# ['gay', 'people', 'clinton', 'government', 'economic']
# ['max', 'tm', 'ah', 'ma', 'la', 'st', 'au', 'sp', 'fi', 'mr']
# 模型结果====================================================================
# ==========================================================================
# 0.0821836205272041
# 主题先验===================================================================
# ['jesus', 'god', 'bible', 'christian', 'kent']
# ['desktop', 'microsoft', 'apple', 'mac', 'windows', 'keyboard', 'os', 'rear', 'characters', 'screen']
# 模型结果====================================================================
# epoch end====================================================================
# ==========================================================================
# ==========================================================================
# epoch start ====================================================================
# cur reconstruct loss: 82684.78125
# cur total  loss: 82684.78125
# ==========================================================================
# f1 macro: 0.004989159771035383 f1 micro: 0.05059634737234439 precision: 0.05059634737234439 accuracy: 0.05059634737234439 recall 0.05059634737234439
# ==========================================================================
# Average Topic Coherence = 0.184
# Average  gaton Topic Coherence = -230.674
# ==========================================================================
# 0.22180747716980392
# 主题先验===================================================================
# ['atheism', 'atheists', 'religion', 'atheist', 'god']
# ['max', 'ah', 'tm', 'sp', 'ma', 'ide', 'scsi', 'id', 'controller', 'hd']
# 模型结果====================================================================
# ==========================================================================
# 0.1860104707921222
# 主题先验===================================================================
# ['graphics', 'image', 'images', 'gif', 'format']
# ['ah', 'sp', 'la', 'pp', 'shots', 'rangers', 'playoff', 'van', 'detroit', 'wings']
# 模型结果====================================================================
# ==========================================================================
# 0.36272394079217785
# 主题先验===================================================================
# ['windows', 'dos', 'file', 'ms', 'microsoft']
# ['morality', 'gods', 'belief', 'objective', 'atheism', 'faith', 'atheists', 'god', 'spirit', 'eternal']
# 模型结果====================================================================
# ==========================================================================
# -0.25365454710380914
# 主题先验===================================================================
# ['ide', 'controller', 'card', 'bus', 'drive']
# ['theory', 'rear', 'science', 'interpretation', 'gay', 'bible', 'lights', 'patients', 'cars', 'christianity']
# 模型结果====================================================================
# ==========================================================================
# -0.04757047733521399
# 主题先验===================================================================
# ['mac', 'apple', 'monitor', 'scsi', 'se']
# ['max', 'ah', 'tm', 'sp', 'ma', 'pp', 'pitt', 'doug', 'buffalo', 'gordon']
# 模型结果====================================================================
# ==========================================================================
# 0.2325377734266669
# 主题先验===================================================================
# ['window', 'motif', 'server', 'widget', 'application']
# ['scsi', 'rom', 'microsoft', 'disk', 'card', 'copies', 'backup', 'feature', 'characters', 'windows']
# 模型结果====================================================================
# ==========================================================================
# 0.1330407278446686
# 主题先验===================================================================
# ['sale', 'shipping', 'offer', 'condition', 'sell']
# ['output', 'entry', 'amendment', 'theory', 'characters', 'rate', 'drug', 'rates', 'file', 'maximum']
# 模型结果====================================================================
# ==========================================================================
# 0.13802960835581896
# 主题先验===================================================================
# ['car', 'cars', 'engine', 'ford', 'dealer']
# ['dealer', 'privacy', 'company', 'software', 'packages', 'microsoft', 'companies', 'encrypted', 'tax', 'data']
# 模型结果====================================================================
# ==========================================================================
# 0.26029050388510083
# 主题先验===================================================================
# ['bike', 'dod', 'ride', 'riding', 'rear']
# ['max', 'ah', 'la', 'tm', 'van', 'shots', 'air', 'ma', 'pp', 'ny']
# 模型结果====================================================================
# ==========================================================================
# 0.3307637360976866
# 主题先验===================================================================
# ['baseball', 'game', 'games', 'players', 'league']
# ['microsoft', 'characters', 'windows', 'software', 'font', 'formats', 'format', 'modem', 'fonts', 'image']
# 模型结果====================================================================
# ==========================================================================
# 0.28040845159507116
# 主题先验===================================================================
# ['hockey', 'game', 'team', 'nhl', 'playoffs']
# ['ah', 'sp', 'ma', 'pp', 'la', 'max', 'tm', 'shots', 'ny', 'van']
# 模型结果====================================================================
# ==========================================================================
# 0.4256983056821431
# 主题先验===================================================================
# ['encryption', 'clipper', 'key', 'nsa', 'keys']
# ['gif', 'anonymous', 'motif', 'internet', 'pub', 'ftp', 'usenet', 'libraries', 'server', 'gov']
# 模型结果====================================================================
# ==========================================================================
# 0.22977790221940494
# 主题先验===================================================================
# ['circuit', 'electronics', 'output', 'radio', 'battery']
# ['scsi', 'print', 'copies', 'modem', 'printer', 'pc', 'card', 'characters', 'port', 'books']
# 模型结果====================================================================
# ==========================================================================
# -0.03324614916729911
# 主题先验===================================================================
# ['doctor', 'medical', 'disease', 'patients', 'gordon']
# ['max', 'ah', 'tm', 'sp', 'ma', 'air', 'batf', 'hockey', 'dod', 'st']
# 模型结果====================================================================
# ==========================================================================
# 0.36658711624142587
# 主题先验===================================================================
# ['space', 'orbit', 'shuttle', 'nasa', 'launch']
# ['windows', 'microsoft', 'desktop', 'dos', 'font', 'fonts', 'characters', 'unix', 'software', 'shareware']
# 模型结果====================================================================
# ==========================================================================
# -0.0363299451692647
# 主题先验===================================================================
# ['god', 'christ', 'church', 'jesus', 'christian']
# ['max', 'ah', 'tm', 'sp', 'serdar', 'ma', 'argic', 'turks', 'armenians', 'air']
# 模型结果====================================================================
# ==========================================================================
# 0.181507967892461
# 主题先验===================================================================
# ['gun', 'guns', 'firearms', 'fbi', 'weapons']
# ['max', 'ah', 'sp', 'pp', 'tm', 'ma', 'shots', 'buffalo', 'detroit', 'la']
# 模型结果====================================================================
# ==========================================================================
# 0.06469480881392539
# 主题先验===================================================================
# ['israel', 'israeli', 'arab', 'armenian', 'armenians']
# ['max', 'ah', 'tm', 'turkish', 'pp', 'ma', 'greek', 'la', 'buffalo', 'turkey']
# 模型结果====================================================================
# ==========================================================================
# 0.3527844414579704
# 主题先验===================================================================
# ['gay', 'people', 'clinton', 'government', 'economic']
# ['max', 'tm', 'ah', 'ma', 'la', 'sp', 'st', 'au', 'fi', 'mr']
# 模型结果====================================================================
# ==========================================================================
# 0.2787221808189365
# 主题先验===================================================================
# ['jesus', 'god', 'bible', 'christian', 'kent']
# ['desktop', 'microsoft', 'windows', 'characters', 'apple', 'mac', 'keyboard', 'screen', 'drivers', 'pc']
# 模型结果====================================================================
# epoch end====================================================================
# ==========================================================================
# ==========================================================================
# epoch start ====================================================================
# cur reconstruct loss: 82675.40625
# cur total  loss: 82675.40625
# ==========================================================================
# f1 macro: 0.004837134996006035 f1 micro: 0.05078270592620202 precision: 0.050782705926202015 accuracy: 0.050782705926202015 recall 0.050782705926202015
# ==========================================================================
# Average Topic Coherence = 0.185
# Average  gaton Topic Coherence = -230.201
# ==========================================================================
# 0.17441615044422598
# 主题先验===================================================================
# ['atheism', 'atheists', 'religion', 'atheist', 'god']
# ['max', 'ah', 'tm', 'sp', 'ma', 'ide', 'scsi', 'id', 'gov', 'hd']
# 模型结果====================================================================
# ==========================================================================
# 0.10313576040261364
# 主题先验===================================================================
# ['graphics', 'image', 'images', 'gif', 'format']
# ['ah', 'sp', 'la', 'pp', 'shots', 'rangers', 'van', 'playoff', 'ma', 'detroit']
# 模型结果====================================================================
# ==========================================================================
# 0.36388330353932086
# 主题先验===================================================================
# ['windows', 'dos', 'file', 'ms', 'microsoft']
# ['morality', 'gods', 'belief', 'objective', 'atheism', 'faith', 'atheists', 'god', 'religions', 'spirit']
# 模型结果====================================================================
# ==========================================================================
# 0.00863427826415955
# 主题先验===================================================================
# ['ide', 'controller', 'card', 'bus', 'drive']
# ['theory', 'rear', 'bible', 'science', 'lights', 'interpretation', 'cars', 'car', 'definition', 'models']
# 模型结果====================================================================
# ==========================================================================
# -0.05233290512137197
# 主题先验===================================================================
# ['mac', 'apple', 'monitor', 'scsi', 'se']
# ['max', 'ah', 'tm', 'sp', 'ma', 'pp', 'pitt', 'air', 'buffalo', 'surrender']
# 模型结果====================================================================
# ==========================================================================
# 0.24079705023763592
# 主题先验===================================================================
# ['window', 'motif', 'server', 'widget', 'application']
# ['microsoft', 'windows', 'characters', 'scsi', 'rom', 'disk', 'card', 'software', 'modem', 'feature']
# 模型结果====================================================================
# ==========================================================================
# 0.18472257753713026
# 主题先验===================================================================
# ['sale', 'shipping', 'offer', 'condition', 'sell']
# ['output', 'characters', 'microsoft', 'entry', 'windows', 'file', 'sound', 'theory', 'compression', 'input']
# 模型结果====================================================================
# ==========================================================================
# 0.16487128258356626
# 主题先验===================================================================
# ['car', 'cars', 'engine', 'ford', 'dealer']
# ['microsoft', 'software', 'privacy', 'dealer', 'company', 'packages', 'companies', 'encrypted', 'files', 'data']
# 模型结果====================================================================
# ==========================================================================
# 0.24655605363503033
# 主题先验===================================================================
# ['bike', 'dod', 'ride', 'riding', 'rear']
# ['max', 'ah', 'tm', 'la', 'van', 'ma', 'air', 'shots', 'sp', 'pp']
# 模型结果====================================================================
# ==========================================================================
# 0.33559699507834173
# 主题先验===================================================================
# ['baseball', 'game', 'games', 'players', 'league']
# ['microsoft', 'windows', 'characters', 'software', 'modem', 'formats', 'format', 'font', 'compression', 'fonts']
# 模型结果====================================================================
# ==========================================================================
# 0.18894910223880831
# 主题先验===================================================================
# ['hockey', 'game', 'team', 'nhl', 'playoffs']
# ['ah', 'sp', 'max', 'ma', 'tm', 'pp', 'la', 'air', 'ny', 'pitt']
# 模型结果====================================================================
# ==========================================================================
# 0.4294305583422853
# 主题先验===================================================================
# ['encryption', 'clipper', 'key', 'nsa', 'keys']
# ['gif', 'anonymous', 'internet', 'motif', 'pub', 'ftp', 'libraries', 'server', 'usenet', 'files']
# 模型结果====================================================================
# ==========================================================================
# 0.20716844189819
# 主题先验===================================================================
# ['circuit', 'electronics', 'output', 'radio', 'battery']
# ['modem', 'print', 'characters', 'pc', 'printer', 'microsoft', 'copies', 'card', 'scsi', 'books']
# 模型结果====================================================================
# ==========================================================================
# -0.11625527896915996
# 主题先验===================================================================
# ['doctor', 'medical', 'disease', 'patients', 'gordon']
# ['max', 'ah', 'tm', 'sp', 'ma', 'air', 'batf', 'st', 'pitt', 'serdar']
# 模型结果====================================================================
# ==========================================================================
# 0.33331589122092975
# ...
# 0.32976115568165504
# 主题先验===================================================================
# ['atheism', 'atheists', 'religion', 'atheist', 'god']
# ['max', 'tm', 'ah', 'ma', 'sp', 'air', 'st', 'la', 'pp', 'mb']
# 模型结果====================================================================
# ==========================================================================
# 0.17481488858330352
# 主题先验===================================================================
# ['graphics', 'image', 'images', 'gif', 'format']
# ['max', 'ah', 'tm', 'sp', 'ma', 'la', 'air', 'pp', 'rangers', 'shots']
# 模型结果====================================================================
# ==========================================================================
# 0.3112605977008431
# 主题先验===================================================================
# ['windows', 'dos', 'file', 'ms', 'microsoft']
# ['windows', 'software', 'modem', 'formats', 'microsoft', 'format', 'files', 'computer', 'file', 'data']
# 模型结果====================================================================
# ==========================================================================
# 0.3088770028694702
# 主题先验===================================================================
# ['ide', 'controller', 'card', 'bus', 'drive']
# ['windows', 'microsoft', 'software', 'computer', 'desktop', 'modem', 'formats', 'characters', 'files', 'format']
# 模型结果====================================================================
# ==========================================================================
# 0.17759621316111596
# 主题先验===================================================================
# ['mac', 'apple', 'monitor', 'scsi', 'se']
# ['max', 'tm', 'ah', 'ma', 'sp', 'air', 'la', 'st', 'pp', 'pitt']
# 模型结果====================================================================
# ==========================================================================
# -0.12769238911799366
# 主题先验===================================================================
# ['window', 'motif', 'server', 'widget', 'application']
# ['shots', 'rangers', 'israel', 'arab', 'soldiers', 'detroit', 'wings', 'israeli', 'turkish', 'arabs']
# 模型结果====================================================================
# ==========================================================================
# 0.32523132847542774
# 主题先验===================================================================
# ['sale', 'shipping', 'offer', 'condition', 'sell']
# ['windows', 'microsoft', 'computer', 'software', 'file', 'characters', 'files', 'modem', 'formats', 'format']
# 模型结果====================================================================
# ==========================================================================
# 0.3106206083238131
# 主题先验===================================================================
# ['car', 'cars', 'engine', 'ford', 'dealer']
# ['file', 'computer', 'software', 'files', 'data', 'formats', 'directory', 'company', 'companies', 'entry']
# 模型结果====================================================================
# ==========================================================================
# 0.3180825535486124
# 主题先验===================================================================
# ['bike', 'dod', 'ride', 'riding', 'rear']
# ['max', 'tm', 'ah', 'ma', 'la', 'air', 'sp', 'st', 'van', 'pp']
# 模型结果====================================================================
# ==========================================================================
# 0.3143411925744442
# 主题先验===================================================================
# ['baseball', 'game', 'games', 'players', 'league']
# ['windows', 'microsoft', 'software', 'computer', 'modem', 'formats', 'characters', 'graphics', 'dos', 'shareware']
# 模型结果====================================================================
# ==========================================================================
# 0.17759621316111596
# 主题先验===================================================================
# ['hockey', 'game', 'team', 'nhl', 'playoffs']
# ['max', 'tm', 'ah', 'ma', 'sp', 'air', 'la', 'st', 'pp', 'pitt']
# 模型结果====================================================================
# ==========================================================================
# 0.5279012948349457
# 主题先验===================================================================
# ['encryption', 'clipper', 'key', 'nsa', 'keys']
# ['turkish', 'turks', 'genocide', 'turkey', 'armenian', 'argic', 'greek', 'jews', 'israeli', 'armenia']
# 模型结果====================================================================
# ==========================================================================
# 0.30789919928746384
# 主题先验===================================================================
# ['circuit', 'electronics', 'output', 'radio', 'battery']
# ['windows', 'software', 'microsoft', 'computer', 'formats', 'modem', 'characters', 'graphics', 'format', 'shareware']
# 模型结果====================================================================
# ==========================================================================
# 0.15413639050359237
# 主题先验===================================================================
# ['doctor', 'medical', 'disease', 'patients', 'gordon']
# ['max', 'tm', 'ah', 'ma', 'sp', 'air', 'st', 'mr', 'pitt', 'pp']
# 模型结果====================================================================
# ==========================================================================
# 0.3143411925744442
# 主题先验===================================================================
# ['space', 'orbit', 'shuttle', 'nasa', 'launch']
# ['windows', 'software', 'microsoft', 'modem', 'computer', 'formats', 'graphics', 'characters', 'shareware', 'dos']
# 模型结果====================================================================
# ==========================================================================
# 0.17759621316111596
# 主题先验===================================================================
# ['god', 'christ', 'church', 'jesus', 'christian']
# ['max', 'tm', 'ah', 'ma', 'sp', 'air', 'st', 'la', 'pitt', 'pp']
# 模型结果====================================================================
# ==========================================================================
# 0.17759621316111596
# 主题先验===================================================================
# ['gun', 'guns', 'firearms', 'fbi', 'weapons']
# ['max', 'tm', 'ah', 'ma', 'sp', 'air', 'la', 'st', 'pp', 'pitt']
# 模型结果====================================================================
# ==========================================================================
# 0.3481618555835911
# 主题先验===================================================================
# ['israel', 'israeli', 'arab', 'armenian', 'armenians']
# ['windows', 'microsoft', 'software', 'characters', 'computer', 'formats', 'files', 'shareware', 'format', 'file']
# 模型结果====================================================================
# ==========================================================================
# 0.36269198971410493
# 主题先验===================================================================
# ['gay', 'people', 'clinton', 'government', 'economic']
# ['max', 'tm', 'ah', 'ma', 'sp', 'mb', 'air', 'st', 'au', 'fi']
# 模型结果====================================================================
# ==========================================================================
# 0.1826139900034641
# 主题先验===================================================================
# ['jesus', 'god', 'bible', 'christian', 'kent']
# ['van', 'pp', 'la', 'louis', 'shots', 'detroit', 'rangers', 'buffalo', 'turkish', 'turks']
# 模型结果====================================================================
# epoch end====================================================================
# ==========================================================================
# ==========================================================================
# epoch start ====================================================================
# cur reconstruct loss: 82461.890625
# cur total  loss: 82461.890625
# ==========================================================================
# f1 macro: 0.005194080910559928 f1 micro: 0.04789414834140887 precision: 0.04789414834140887 accuracy: 0.04789414834140887 recall 0.04789414834140887
# ==========================================================================
# Average Topic Coherence = 0.254
# Average  gaton Topic Coherence = -213.772
# ==========================================================================
# 0.32976115568165504
# 主题先验===================================================================
# ['atheism', 'atheists', 'religion', 'atheist', 'god']
# ['max', 'tm', 'ah', 'ma', 'sp', 'air', 'st', 'la', 'pp', 'mb']
# 模型结果====================================================================
# ==========================================================================
# 0.17481488858330352
# 主题先验===================================================================
# ['graphics', 'image', 'images', 'gif', 'format']
# ['max', 'ah', 'tm', 'sp', 'la', 'ma', 'air', 'rangers', 'pp', 'shots']
# 模型结果====================================================================
# ==========================================================================
# 0.3112605977008431
# 主题先验===================================================================
# ['windows', 'dos', 'file', 'ms', 'microsoft']
# ['windows', 'software', 'modem', 'formats', 'microsoft', 'computer', 'format', 'files', 'data', 'file']
# 模型结果====================================================================
# ==========================================================================
# 0.3088770028694702
# 主题先验===================================================================
# ['ide', 'controller', 'card', 'bus', 'drive']
# ['windows', 'microsoft', 'software', 'computer', 'desktop', 'modem', 'formats', 'files', 'format', 'characters']
# 模型结果====================================================================
# ==========================================================================
# 0.17759621316111596
# 主题先验===================================================================
# ['mac', 'apple', 'monitor', 'scsi', 'se']
# ['max', 'tm', 'ah', 'ma', 'sp', 'air', 'la', 'st', 'pp', 'pitt']
# 模型结果====================================================================
# ==========================================================================
# 0.05095229028973358
# 主题先验===================================================================
# ['window', 'motif', 'server', 'widget', 'application']
# ['shots', 'rangers', 'pp', 'louis', 'detroit', 'pitt', 'surrender', 'boston', 'wings', 'buffalo']
# 模型结果====================================================================
# ==========================================================================
# 0.3145608437922908
# 主题先验===================================================================
# ['sale', 'shipping', 'offer', 'condition', 'sell']
# ['windows', 'computer', 'microsoft', 'software', 'file', 'files', 'characters', 'modem', 'computers', 'formats']
# 模型结果====================================================================
# ==========================================================================
# 0.18618654143403046
# 主题先验===================================================================
# ['car', 'cars', 'engine', 'ford', 'dealer']
# ['ford', 'dealer', 'car', 'file', 'cars', 'company', 'companies', 'files', 'entry', 'engine']
# 模型结果====================================================================
# ==========================================================================
# 0.3180825535486124
# 主题先验===================================================================
# ['bike', 'dod', 'ride', 'riding', 'rear']
# ['max', 'tm', 'ah', 'ma', 'la', 'air', 'st', 'sp', 'van', 'pp']
# 模型结果====================================================================
# ==========================================================================
# 0.3143411925744442
# 主题先验===================================================================
# ['baseball', 'game', 'games', 'players', 'league']
# ['windows', 'software', 'microsoft', 'computer', 'modem', 'formats', 'characters', 'graphics', 'dos', 'shareware']
# 模型结果====================================================================
# ==========================================================================
# 0.17759621316111596
# 主题先验===================================================================
# ['hockey', 'game', 'team', 'nhl', 'playoffs']
# ['max', 'tm', 'ah', 'ma', 'sp', 'air', 'la', 'st', 'pp', 'pitt']
# 模型结果====================================================================
# ==========================================================================
# 0.4089806578683739
# 主题先验===================================================================
# ['encryption', 'clipper', 'key', 'nsa', 'keys']
# ['turkish', 'turks', 'turkey', 'genocide', 'argic', 'armenian', 'greek', 'jews', 'shots', 'israeli']
# 模型结果====================================================================
# ==========================================================================
# 0.30789919928746384
# 主题先验===================================================================
# ['circuit', 'electronics', 'output', 'radio', 'battery']
# ['windows', 'software', 'microsoft', 'computer', 'formats', 'characters', 'modem', 'graphics', 'format', 'shareware']
# 模型结果====================================================================
# ==========================================================================
# 0.15061988316719524
# 主题先验===================================================================
# ['doctor', 'medical', 'disease', 'patients', 'gordon']
# ['max', 'tm', 'ah', 'ma', 'sp', 'air', 'st', 'mr', 'mb', 'pitt']
# 模型结果====================================================================
# ==========================================================================
# 0.3143411925744442
# 主题先验===================================================================
# ['space', 'orbit', 'shuttle', 'nasa', 'launch']
# ['windows', 'software', 'microsoft', 'computer', 'modem', 'formats', 'graphics', 'characters', 'shareware', 'dos']
# 模型结果====================================================================
# ==========================================================================
# 0.17759621316111598
# 主题先验===================================================================
# ['god', 'christ', 'church', 'jesus', 'christian']
# ['max', 'tm', 'ah', 'ma', 'sp', 'air', 'st', 'la', 'pp', 'pitt']
# 模型结果====================================================================
# ==========================================================================
# 0.17759621316111596
# 主题先验===================================================================
# ['gun', 'guns', 'firearms', 'fbi', 'weapons']
# ['max', 'tm', 'ah', 'ma', 'sp', 'air', 'la', 'st', 'pp', 'pitt']
# 模型结果====================================================================
# ==========================================================================
# 0.32007965210820943
# 主题先验===================================================================
# ['israel', 'israeli', 'arab', 'armenian', 'armenians']
# ['windows', 'software', 'microsoft', 'computer', 'characters', 'formats', 'files', 'shareware', 'format', 'modem']
# 模型结果====================================================================
# ==========================================================================
# 0.1835713321090951
# 主题先验===================================================================
# ['gay', 'people', 'clinton', 'government', 'economic']
# ['max', 'tm', 'windows', 'ah', 'modem', 'microsoft', 'software', 'computer', 'ma', 'formats']
# 模型结果====================================================================
# ==========================================================================
# 0.3772724303650442
# 主题先验===================================================================
# ['jesus', 'god', 'bible', 'christian', 'kent']
# ['van', 'la', 'pp', 'shots', 'louis', 'rangers', 'detroit', 'buffalo', 'period', 'boston']
# 模型结果====================================================================
# epoch end====================================================================
# ==========================================================================
